# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
###cleaning

def clean_(df):
    df.replace('-',np.nan,inplace=True)
    df=df.fillna(0)
    return df

# %% [markdown]
# #### Stats function

# %%
def Batting_hand(df):
    Batting_style=pd.DataFrame(round(df['Batting_style'].value_counts()/df['Batting_style'].value_counts().sum()*100,2))
    Batting_style=Batting_style.reset_index()
    plt.figure(figsize=(16,8))
    # plot chart
    ax1 = plt.subplot(121, aspect='equal')
    Batting_style.plot(kind='pie', y = 'Batting_style', ax=ax1, autopct='%1.1f%%', 
     startangle=90, shadow=False, labels=Batting_style['index'], legend = False, fontsize=14)

# %%
def skill_distribution(df):
    skill=pd.DataFrame(round(df['Skill'].value_counts()/df['Skill'].value_counts().sum()*100,2))
    skill=skill.reset_index()
    plt.figure(figsize=(16,8))
    # plot chart
    ax1 = plt.subplot(121, aspect='equal')
    skill.plot(kind='pie', y = 'Skill', ax=ax1, autopct='%1.1f%%', 
     startangle=90, shadow=False, labels=skill['index'], legend = False, fontsize=14)

# %%
def Age_distribution(df):
    plt.figure(figsize=(16,8))
    df.Age.plot(kind='kde')
    print("The average age of the team being ",round(df.Age.mean()))
    print("Youngest player age of the team being",df.Age.min())
    print("most experienced player age of the team being ",df.Age.max())

# %%
def Bowling_variation(df):
    Bowling_style=pd.DataFrame(round(df['Bowling_style'].value_counts()/df['Bowling_style'].value_counts().sum()*100,2))
    Bowling_style=Bowling_style.reset_index()
    plt.figure(figsize=(16,8))
    # plot chart
    ax1 = plt.subplot(121, aspect='equal')
    Bowling_style.plot(kind='pie', y = 'Bowling_style', ax=ax1, autopct='%1.1f%%', 
    startangle=90, shadow=False, labels=Bowling_style['index'], legend = False, fontsize=14)

# %%
def most_match(df):
    df['Mat_FC']=df['Mat_FC'].astype(int)
    print(df[['name','Mat_FC']].nlargest(5, 'Mat_FC').set_index('name'))
    
def Most_runs(df):
    df['Runs_FC']=df['Runs_FC'].astype(int)
    print(df[['name','Runs_FC']].nlargest(5, 'Runs_FC').set_index('name'))
    
def Bat_strike(df):
    df['Bat_SR_FC']=df['Bat_SR_FC'].astype(float)
    print(df[['name','Bat_SR_FC']].nlargest(5, 'Bat_SR_FC').set_index('name'))

# %%
def Bowling_Ave(df):
    df['Bowl_Ave_FC']=df['Bowl_Ave_FC'].astype(float)
    print(df[(df['Bowl_Ave_FC']>0) & ((df['Skill']=='Bowler') |(df['Skill']=='Allrounder'))][['name','Bowl_Ave_FC']].nsmallest(5, 'Bowl_Ave_FC').set_index('name'))
def Most_Wks(df):
    df['Wkts_FC']=df['Wkts_FC'].fillna(0).astype(int)
    print(df[(df['Wkts_FC']>0) & ((df['Skill']=='Bowler') |(df['Skill']=='Allrounder'))][['name','Wkts_FC']].nlargest(5, 'Wkts_FC').set_index('name'))
def Best_eco(df):
    df['Econ_FC']=df['Econ_FC'].astype(float)
    print(df[(df['Econ_FC']>0) & ((df['Skill']=='Bowler') |(df['Skill']=='Allrounder'))][['name','Econ_FC']].nsmallest(5, 'Econ_FC').set_index('name'))

# %% [markdown]
# ## Stats

# %% [markdown]
# #### Chennai Super king stats

# %%
csk=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\csk.csv')
df=clean_(csk)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# None
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  31
# Youngest player age of the team being 22
# most experienced player age of the team being  41
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                Mat_FC
# name
# Dwayne Bravo      465
# Shane Watson      335
# MS Dhoni          320
# Imran Tahir       301
# Piyush Chawla     240
# Top Run scorers
# **************************************************
#                 Runs_FC
# name
# Shane Watson       8573
# MS Dhoni           6665
# Dwayne Bravo       6324
# Faf du Plessis     5431
# Ambati Rayudu      4829
# Top best players with the best strikerate
# **************************************************
#                  Bat_SR_FC
# name
# Shane Watson        138.87
# MS Dhoni            135.66
# Ruturaj Gaikwad     133.75
# Sam Curran          133.63
# Deepak Chahar       133.33
# Top 5 Best Bowling Average
# **************************************************
#                             Bowl_Ave_FC
# name
# Ravisrinivasan Sai Kishore        16.76
# Lungi Ngidi                       18.55
# Imran Tahir                       19.69
# Deepak Chahar                     20.68
# KM Asif                           20.81
# Top 5 Best economy rate
# **************************************************
#                             Econ_FC
# name
# Ravisrinivasan Sai Kishore     5.45
# Monu Kumar                     6.90
# Imran Tahir                    6.96
# Mitchell Santner               7.00
# Deepak Chahar                  7.33
# Top 5 most wicket in the team
# **************************************************
#                  Wkts_FC
# name
# Dwayne Bravo         506
# Imran Tahir          380
# Piyush Chawla        255
# Shane Watson         216
# Ravindra Jadeja      160

# %% [markdown]
# #### Mumbai Indian

# %%
mi=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\mi.csv')
df=clean_(mi)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 21
# most experienced player age of the team being  34
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                       Mat_FC
# name
# Kieron Pollard           514
# Rohit Sharma             330
# Chris Lynn               193
# Mitchell McClenaghan     193
# Quinton de Kock          186
# Top Run scorers
# **************************************************
#                   Runs_FC
# name
# Kieron Pollard      10238
# Rohit Sharma         8734
# Quinton de Kock      5544
# Chris Lynn           5234
# Suryakumar Yadav     3076
# Top best players with the best strikerate
# **************************************************
#                   Bat_SR_FC
# name
# Kieron Pollard       151.38
# Chris Lynn           142.88
# Hardik Pandya        139.70
# Suryakumar Yadav     139.24
# Quinton de Kock      138.56
# Top 5 Best Bowling Average
# **************************************************
#                      Bowl_Ave_FC
# name
# Mohsin Khan                18.30
# Rahul Chahar               22.33
# Jasprit Bumrah             22.55
# Nathan Coulter-Nile        23.38
# James Pattinson            23.72
# Top 5 Best economy rate
# **************************************************
#                 Econ_FC
# name
# Jayant Yadav       6.20
# Anukul Roy         6.85
# Mohsin Khan        7.00
# Jasprit Bumrah     7.09
# Rahul Chahar       7.15
# Top 5 most wicket in the team
# **************************************************
#                       Wkts_FC
# name
# Kieron Pollard            288
# Mitchell McClenaghan      229
# Jasprit Bumrah            185
# Dhawal Kulkarni           147
# Nathan Coulter-Nile       140

# %% [markdown]
# #### Royal Challengers Bangalore

# %%
rcb=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\rcb.csv')
df=clean_(rcb)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  29
# Youngest player age of the team being 20
# most experienced player age of the team being  37
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                 Mat_FC
# name
# AB de Villiers     312
# Aaron Finch        289
# Virat Kohli        283
# Dale Steyn         222
# Chris Morris       209
# Top Run scorers
# **************************************************
#                 Runs_FC
# name
# Aaron Finch        9088
# Virat Kohli        8915
# AB de Villiers     8736
# Parthiv Patel      4300
# Moeen Ali          3501
# Top best players with the best strikerate
# **************************************************
#                   Bat_SR_FC
# name
# Devdutt Padikkal     170.32
# Chris Morris         150.82
# AB de Villiers       149.89
# Pavan Deshpande      149.47
# Aaron Finch          143.34
# Top 5 Best Bowling Average
# **************************************************
#                 Bowl_Ave_FC
# name
# Dale Steyn            21.74
# Adam Zampa            21.83
# Chris Morris          22.22
# Shahbaz Ahmed         22.53
# Mohammed Siraj        22.54
# Top 5 Best economy rate
# **************************************************
#                    Econ_FC
# name
# Shahbaz Ahmed         6.37
# Washington Sundar     6.74
# Dale Steyn            6.80
# Navdeep Saini         7.12
# Adam Zampa            7.29
# Top 5 most wicket in the team
# **************************************************
#                   Wkts_FC
# name
# Chris Morris          259
# Dale Steyn            257
# Yuzvendra Chahal      193
# Adam Zampa            172
# Umesh Yadav           148

# %% [markdown]
# #### Kolkata Knight Riders

# %%
kkr=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\kkr.csv')
df=clean_(kkr)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 20
# most experienced player age of the team being  35
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                 Mat_FC
# name
# Sunil Narine       343
# Andre Russell      332
# Eoin Morgan        292
# Dinesh Karthik     290
# Nitish Rana         98
# Top Run scorers
# **************************************************
#                 Runs_FC
# name
# Eoin Morgan        6481
# Dinesh Karthik     5738
# Andre Russell      5598
# Sunil Narine       2394
# Nitish Rana        2160
# Top best players with the best strikerate
# **************************************************
#                Bat_SR_FC
# name
# Andre Russell     169.63
# Tom Banton        154.16
# Sunil Narine      146.51
# Rinku Singh       137.97
# Nitish Rana       135.93
# Top 5 Best Bowling Average
# **************************************************
#                      Bowl_Ave_FC
# name
# Manimaran Siddharth         7.41
# Sunil Narine               20.37
# Kuldeep Yadav              21.58
# Pat Cummins                24.87
# Andre Russell              25.94
# Top 5 Best economy rate
# **************************************************
#                      Econ_FC
# name
# Manimaran Siddharth     4.94
# Sunil Narine            6.01
# Chris Green             6.64
# Sandeep Warrier         7.27
# Kuldeep Yadav           7.56
# Top 5 most wicket in the team
# **************************************************
#                Wkts_FC
# name
# Sunil Narine       386
# Andre Russell      296
# Kuldeep Yadav      119
# Pat Cummins         98
# Chris Green         74

# %% [markdown]
# #### Sunrisers Hyderabad

# %%
srh=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\srh.csv')
df=clean_(srh)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 18
# most experienced player age of the team being  35
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                  Mat_FC
# name
# David Warner        284
# Mohammad Nabi       271
# Manish Pandey       242
# Rashid Khan         223
# Wriddhiman Saha     192
# Top Run scorers
# **************************************************
#                  Runs_FC
# name
# David Warner        9318
# Manish Pandey       5409
# Kane Williamson     4593
# Mohammad Nabi       4118
# Wriddhiman Saha     3262
# Top best players with the best strikerate
# **************************************************
#                  Bat_SR_FC
# name
# Fabian Allen        164.89
# Abhishek Sharma     150.51
# Rashid Khan         146.28
# David Warner        141.86
# Mohammad Nabi       141.31
# Top 5 Best Bowling Average
# **************************************************
#                  Bowl_Ave_FC
# name
# Abhishek Sharma        17.00
# Rashid Khan            17.54
# Khaleel Ahmed          19.25
# Mohammad Nabi          23.34
# Sandeep Sharma         23.85
# Top 5 Best economy rate
# **************************************************
#                    Econ_FC
# name
# Rashid Khan           6.33
# Shahbaz Nadeem        6.74
# Mohammad Nabi         6.89
# Bhuvneshwar Kumar     7.19
# T Natarajan           7.22
# Top 5 most wicket in the team
# **************************************************
#                    Wkts_FC
# name
# Rashid Khan            308
# Mohammad Nabi          267
# Bhuvneshwar Kumar      182
# Sandeep Sharma         138
# Siddarth Kaul          114

# %% [markdown]
# #### Kings XI Punjab

# %%
kxip=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\kxip.csv')
df=clean_(kxip)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 19
# most experienced player age of the team being  41
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                  Mat_FC
# name
# Chris Gayle         404
# Glenn Maxwell       273
# Chris Jordan        201
# Mandeep Singh       165
# Nicholas Pooran     140
# Top Run scorers
# **************************************************
#                 Runs_FC
# name
# Chris Gayle       13296
# Glenn Maxwell      6022
# KL Rahul           4229
# Mandeep Singh      3251
# Mayank Agarwal     3084
# Top best players with the best strikerate
# **************************************************
#                     Bat_SR_FC
# name
# Krishnappa Gowtham     161.97
# Glenn Maxwell          153.77
# Chris Gayle            146.94
# Tajinder Singh         144.16
# KL Rahul               141.15
# Top 5 Best Bowling Average
# **************************************************
#                   Bowl_Ave_FC
# name
# Darshan Nalkande        12.94
# Tajinder Singh          16.11
# Ravi Bishnoi            19.20
# Harpreet Brar           19.35
# Sheldon Cottrell        19.47
# Top 5 Best economy rate
# **************************************************
#                   Econ_FC
# name
# Ishan Porel          6.11
# Tajinder Singh       6.52
# Mujeeb Ur Rahman     6.60
# Ravi Bishnoi         6.62
# Mandeep Singh        6.67
# Top 5 most wicket in the team
# **************************************************
#                   Wkts_FC
# name
# Chris Jordan          213
# Hardus Viljoen        140
# Sheldon Cottrell      132
# Mujeeb Ur Rahman      131
# James Neesham         113

# %% [markdown]
# #### Rajasthan Royals

# %%
rr=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\rr.csv')
df=clean_(rr)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  26
# Youngest player age of the team being 18
# most experienced player age of the team being  34
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                Mat_FC
# name
# David Miller      320
# Robin Uthappa     257
# Jos Buttler       254
# Steven Smith      193
# Sanju Samson      150
# Top Run scorers
# **************************************************
#                Runs_FC
# name
# David Miller      6900
# Robin Uthappa     6509
# Jos Buttler       5903
# Steven Smith      4114
# Sanju Samson      3555
# Top best players with the best strikerate
# **************************************************
#                  Bat_SR_FC
# name
# Rahul Tewatia       153.73
# Aniruddha Joshi     146.89
# Jofra Archer        144.80
# Jos Buttler         144.75
# Shashank Singh      141.14
# Top 5 Best Bowling Average
# **************************************************
#                  Bowl_Ave_FC
# name
# Aniruddha Joshi        12.33
# Akash Singh            13.00
# Shreyas Gopal          17.05
# Ankit Rajpoot          18.97
# Andrew Tye             21.47
# Top 5 Best economy rate
# **************************************************
#                  Econ_FC
# name
# Akash Singh         6.50
# Shreyas Gopal       7.20
# Rahul Tewatia       7.23
# Mahipal Lomror      7.35
# Aniruddha Joshi     7.40
# Top 5 most wicket in the team
# **************************************************
#                 Wkts_FC
# name
# Andrew Tye          194
# Jaydev Unadkat      168
# Tom Curran          153
# Jofra Archer        125
# Ankit Rajpoot        97

# %% [markdown]
# #### Delhi Capitals

# %%
dc=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\Flask_app\dc.csv')
df=clean_(dc)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 20
# most experienced player age of the team being  37
# Bowling variety available
# **************************************************

# %%
###### print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(mi)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# **************************************************
#                      Mat_FC
# name
# Shikhar Dhawan          261
# Ravichandran Ashwin     233
# Amit Mishra             230
# Ajinkya Rahane          196
# Axar Patel              133
# Top Run scorers
# **************************************************
#                   Runs_FC
# name
# Kieron Pollard      10238
# Rohit Sharma         8734
# Quinton de Kock      5544
# Chris Lynn           5234
# Suryakumar Yadav     3076
# Top best players with the best strikerate
# **************************************************
#                Bat_SR_FC
# name
# Rishabh Pant      155.41
# Harshal Patel     153.81
# Prithvi Shaw      147.86
# Lalit Yadav       136.91
# Shreyas Iyer      130.60
# Top 5 Best Bowling Average
# **************************************************
#                     Bowl_Ave_FC
# name
# Tushar Deshpande          17.93
# Sandeep Lamichhane        18.15
# Daniel Sams               18.36
# Kagiso Rabada             20.91
# Anrich Nortje             22.06
# Top 5 Best economy rate
# **************************************************
#                      Econ_FC
# name
# Sandeep Lamichhane      6.71
# Ravichandran Ashwin     6.87
# Axar Patel              6.90
# Lalit Yadav             6.92
# Amit Mishra             7.17
# Top 5 most wicket in the team
# **************************************************
#                      Wkts_FC
# name
# Amit Mishra              253
# Ravichandran Ashwin      237
# Sandeep Lamichhane       117
# Axar Patel               116
# Kagiso Rabada            112
