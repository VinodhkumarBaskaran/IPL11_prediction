# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
###cleaning

def clean_(df):
    df.replace('-',np.nan,inplace=True)
    df=df.fillna(0)
    return df

# %% [markdown]
# ### CSK

# %%
csk=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\csk.csv')

# %%
csk.drop('Unnamed: 0',axis=1,inplace=True)

# %%
csk=clean_(csk)

# %%
csk['Batting_style'].value_counts()/csk['Batting_style'].value_counts().sum()*100
# Out:
# Right-hand bat    68.181818
# Left-hand bat     31.818182
# Name: Batting_style, dtype: float64

# %%
Batting_style=pd.DataFrame(round(csk['Batting_style'].value_counts()/csk['Batting_style'].value_counts().sum()*100,2))
Batting_style=Batting_style.reset_index()
plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
Batting_style.plot(kind='pie', y = 'Batting_style', ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=Batting_style['index'], legend = False, fontsize=14)

# %%
skill=pd.DataFrame(round(csk['Skill'].value_counts()/csk['Skill'].value_counts().sum()*100,2))
skill=skill.reset_index()
plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
skill.plot(kind='pie', y = 'Skill', ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=skill['index'], legend = False, fontsize=14)

# %%
csk.Age.plot(kind='kde')
print("The average age of the team being ",round(csk.Age.mean()))
print("Youngest player age of the team being",csk.Age.min())
print("most experienced player age of the team being ",csk.Age.max())
# Out:
# The average age of the team being  31
# Youngest player age of the team being 22
# most experienced player age of the team being  41

# %%
Bowling_style=pd.DataFrame(round(csk['Bowling_style'].value_counts()/csk['Bowling_style'].value_counts().sum()*100,2))
Bowling_style=Bowling_style.reset_index()
plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
Bowling_style.plot(kind='pie', y = 'Bowling_style', ax=ax1, autopct='%1.1f%%', 
startangle=90, shadow=False, labels=Bowling_style['index'], legend = False, fontsize=14)

# %%
csk.columns
# Out:
# Index(['name', 'player_status', 'player_stat', 'country', 'Age', 'Major_team',
#        'uncapped', 'Specialist', 'Batting_style', 'Bowling_style', 'Mat_in',
#        'Runs_in', 'HS_in', 'Bat_avg_in', 'Bat_SR_in', 'Wkts_in', 'Bowl_Ave_in',
#        'Econ_in', 'Bowl_SR_in', 'Mat_FC', 'Runs_FC', 'HS_FC', 'Bat_avg_FC',
#        'Bat_SR_FC', 'Wkts_FC', 'Bowl_Ave_FC', 'Econ_FC', 'Bowl_SR_FC',
#        'Skill'],
#       dtype='object')

# %%
csk[['name','Runs_FC']].nlargest(5, 'Runs_FC').set_index('name')
# Out:
#                 Runs_FC
# name
# Shane Watson       8573
# MS Dhoni           6665
# Dwayne Bravo       6324
# Faf du Plessis     5431
# Ambati Rayudu      4829

# %%
csk[['name','Bat_SR_FC']].nlargest(5, 'Bat_SR_FC').set_index('name')
# Out:
#                  Bat_SR_FC
# name
# Shane Watson        138.87
# MS Dhoni            135.66
# Ruturaj Gaikwad     133.75
# Sam Curran          133.63
# Deepak Chahar       133.33

# %%
csk['Bowl_Ave_FC']=csk['Bowl_Ave_FC'].astype(float)
csk[(csk['Bowl_Ave_FC']>0) & ((csk['Skill']=='Bowler') |(csk['Skill']=='Allrounder'))][['name','Bowl_Ave_FC']].nsmallest(5, 'Bowl_Ave_FC').set_index('name')
# Out:
#                             Bowl_Ave_FC
# name
# Ravisrinivasan Sai Kishore        16.76
# Lungi Ngidi                       18.55
# Imran Tahir                       19.69
# Deepak Chahar                     20.68
# KM Asif                           20.81

# %%
csk['Wkts_FC']=csk['Wkts_FC'].astype(int)
csk[(csk['Wkts_FC']>0) & ((csk['Skill']=='Bowler') |(csk['Skill']=='Allrounder'))][['name','Wkts_FC']].nlargest(5, 'Wkts_FC').set_index('name')
# Out:
#                  Wkts_FC
# name
# Dwayne Bravo         506
# Imran Tahir          380
# Piyush Chawla        255
# Shane Watson         216
# Ravindra Jadeja      160

# %%
csk['Econ_FC']=csk['Econ_FC'].astype(float)
csk[(csk['Econ_FC']>0) & ((csk['Skill']=='Bowler') |(csk['Skill']=='Allrounder'))][['name','Econ_FC']].nsmallest(5, 'Econ_FC').set_index('name')
# Out:
#                             Econ_FC
# name
# Ravisrinivasan Sai Kishore     5.45
# Monu Kumar                     6.90
# Imran Tahir                    6.96
# Mitchell Santner               7.00
# Deepak Chahar                  7.33

# %%
def Batting_hand(df):
    Batting_style=pd.DataFrame(round(df['Batting_style'].value_counts()/df['Batting_style'].value_counts().sum()*100,2))
    Batting_style=Batting_style.reset_index()
    plt.figure(figsize=(16,8))
    # plot chart
    ax1 = plt.subplot(121, aspect='equal')
    Batting_style.plot(kind='pie', y = 'Batting_style', ax=ax1, autopct='%1.1f%%', 
     startangle=90, shadow=False, labels=Batting_style['index'], legend = False, fontsize=14)

# %%
def skill_distribution(df):
    skill=pd.DataFrame(round(df['Skill'].value_counts()/df['Skill'].value_counts().sum()*100,2))
    skill=skill.reset_index()
    plt.figure(figsize=(16,8))
    # plot chart
    ax1 = plt.subplot(121, aspect='equal')
    skill.plot(kind='pie', y = 'Skill', ax=ax1, autopct='%1.1f%%', 
     startangle=90, shadow=False, labels=skill['index'], legend = False, fontsize=14)

# %%
def Age_distribution(df):
    plt.figure(figsize=(16,8))
    df.Age.plot(kind='kde')
    print("The average age of the team being ",round(df.Age.mean()))
    print("Youngest player age of the team being",df.Age.min())
    print("most experienced player age of the team being ",df.Age.max())

# %%
def Bowling_variation(df):
    Bowling_style=pd.DataFrame(round(df['Bowling_style'].value_counts()/df['Bowling_style'].value_counts().sum()*100,2))
    Bowling_style=Bowling_style.reset_index()
    plt.figure(figsize=(16,8))
    # plot chart
    ax1 = plt.subplot(121, aspect='equal')
    Bowling_style.plot(kind='pie', y = 'Bowling_style', ax=ax1, autopct='%1.1f%%', 
    startangle=90, shadow=False, labels=Bowling_style['index'], legend = False, fontsize=14)

# %%
def most_match(df):
    print(df[['name','Mat_FC']].nlargest(5, 'Mat_FC').set_index('name'))
    
def Most_runs(df):
    print(df[['name','Runs_FC']].nlargest(5, 'Runs_FC').set_index('name'))
    
def Bat_strike(df):
    print(df[['name','Bat_SR_FC']].nlargest(5, 'Bat_SR_FC').set_index('name'))

# %%
def Bowling_Ave(df):
    df['Bowl_Ave_FC']=df['Bowl_Ave_FC'].astype(float)
    print(df[(df['Bowl_Ave_FC']>0) & ((df['Skill']=='Bowler') |(df['Skill']=='Allrounder'))][['name','Bowl_Ave_FC']].nsmallest(5, 'Bowl_Ave_FC').set_index('name'))
def Most_Wks(df):
    df['Wkts_FC']=df['Wkts_FC'].fillna(0).astype(int)
    print(df[(df['Wkts_FC']>0) & ((df['Skill']=='Bowler') |(df['Skill']=='Allrounder'))][['name','Wkts_FC']].nlargest(5, 'Wkts_FC').set_index('name'))
def Best_eco(df):
    df['Econ_FC']=df['Econ_FC'].astype(float)
    print(df[(df['Econ_FC']>0) & ((df['Skill']=='Bowler') |(df['Skill']=='Allrounder'))][['name','Econ_FC']].nsmallest(5, 'Econ_FC').set_index('name'))

# %% [markdown]
# ## Stats

# %% [markdown]
# #### Chennai Super king stats

# %%
csk=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\csk.csv')
df=clean_(csk)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  31
# Youngest player age of the team being 22
# most experienced player age of the team being  41
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                Mat_FC
# name
# Dwayne Bravo      465
# Shane Watson      335
# MS Dhoni          320
# Imran Tahir       301
# Piyush Chawla     240
# Top Run scorers
# **************************************************
#                 Runs_FC
# name
# Shane Watson       8573
# MS Dhoni           6665
# Dwayne Bravo       6324
# Faf du Plessis     5431
# Ambati Rayudu      4829
# Top best players with the best strikerate
# **************************************************
#                  Bat_SR_FC
# name
# Shane Watson        138.87
# MS Dhoni            135.66
# Ruturaj Gaikwad     133.75
# Sam Curran          133.63
# Deepak Chahar       133.33
# Top 5 Best Bowling Average
# **************************************************
#                             Bowl_Ave_FC
# name
# Ravisrinivasan Sai Kishore        16.76
# Lungi Ngidi                       18.55
# Imran Tahir                       19.69
# Deepak Chahar                     20.68
# KM Asif                           20.81
# Top 5 Best economy rate
# **************************************************
#                             Econ_FC
# name
# Ravisrinivasan Sai Kishore     5.45
# Monu Kumar                     6.90
# Imran Tahir                    6.96
# Mitchell Santner               7.00
# Deepak Chahar                  7.33
# Top 5 most wicket in the team
# **************************************************
#                  Wkts_FC
# name
# Dwayne Bravo         506
# Imran Tahir          380
# Piyush Chawla        255
# Shane Watson         216
# Ravindra Jadeja      160

# %% [markdown]
# #### Mumbai Indian

# %%
mi=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\mi.csv')
df=clean_(mi)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 21
# most experienced player age of the team being  34
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                       Mat_FC
# name
# Kieron Pollard           514
# Rohit Sharma             330
# Chris Lynn               193
# Mitchell McClenaghan     193
# Quinton de Kock          186
# Top Run scorers
# **************************************************
#                   Runs_FC
# name
# Kieron Pollard      10238
# Rohit Sharma         8734
# Quinton de Kock      5544
# Chris Lynn           5234
# Suryakumar Yadav     3076
# Top best players with the best strikerate
# **************************************************
#                   Bat_SR_FC
# name
# Kieron Pollard       151.38
# Chris Lynn           142.88
# Hardik Pandya        139.70
# Suryakumar Yadav     139.24
# Quinton de Kock      138.56
# Top 5 Best Bowling Average
# **************************************************
#                      Bowl_Ave_FC
# name
# Mohsin Khan                18.30
# Rahul Chahar               22.33
# Jasprit Bumrah             22.55
# Nathan Coulter-Nile        23.38
# James Pattinson            23.72
# Top 5 Best economy rate
# **************************************************
#                 Econ_FC
# name
# Jayant Yadav       6.20
# Anukul Roy         6.85
# Mohsin Khan        7.00
# Jasprit Bumrah     7.09
# Rahul Chahar       7.15
# Top 5 most wicket in the team
# **************************************************
#                       Wkts_FC
# name
# Kieron Pollard            288
# Mitchell McClenaghan      229
# Jasprit Bumrah            185
# Dhawal Kulkarni           147
# Nathan Coulter-Nile       140

# %% [markdown]
# #### Royal Challengers Bangalore

# %%
rcb=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\rcb.csv')
df=clean_(rcb)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  29
# Youngest player age of the team being 20
# most experienced player age of the team being  37
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                 Mat_FC
# name
# AB de Villiers     312
# Aaron Finch        289
# Virat Kohli        283
# Dale Steyn         222
# Chris Morris       209
# Top Run scorers
# **************************************************
#                 Runs_FC
# name
# Aaron Finch        9088
# Virat Kohli        8915
# AB de Villiers     8736
# Parthiv Patel      4300
# Moeen Ali          3501
# Top best players with the best strikerate
# **************************************************
#                   Bat_SR_FC
# name
# Devdutt Padikkal     170.32
# Chris Morris         150.82
# AB de Villiers       149.89
# Pavan Deshpande      149.47
# Aaron Finch          143.34
# Top 5 Best Bowling Average
# **************************************************
#                 Bowl_Ave_FC
# name
# Dale Steyn            21.74
# Adam Zampa            21.83
# Chris Morris          22.22
# Shahbaz Ahmed         22.53
# Mohammed Siraj        22.54
# Top 5 Best economy rate
# **************************************************
#                    Econ_FC
# name
# Shahbaz Ahmed         6.37
# Washington Sundar     6.74
# Dale Steyn            6.80
# Navdeep Saini         7.12
# Adam Zampa            7.29
# Top 5 most wicket in the team
# **************************************************
#                   Wkts_FC
# name
# Chris Morris          259
# Dale Steyn            257
# Yuzvendra Chahal      193
# Adam Zampa            172
# Umesh Yadav           148

# %% [markdown]
# #### Kolkata Knight Riders

# %%
kkr=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\kkr.csv')
df=clean_(kkr)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 20
# most experienced player age of the team being  35
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                 Mat_FC
# name
# Sunil Narine       343
# Andre Russell      332
# Eoin Morgan        292
# Dinesh Karthik     290
# Nitish Rana         98
# Top Run scorers
# **************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-231-4c2c92fd341d> in <module>
#       6 print("Top Run scorers")
#       7 print("*"*50)
# ----> 8 Most_runs(df)
#       9
#      10
#
# <ipython-input-124-8e31bb19b438> in Most_runs(df)
#       3
#       4 def Most_runs(df):
# ----> 5     print(df[['name','Runs_FC']].nlargest(5, 'Runs_FC').set_index('name'))
#       6
#       7 def Bat_strike(df):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    5123         Brunei      434000    12128      BN
#    5124         """
# -> 5125         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5126
#    5127     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1081
#    1082     def nlargest(self):
# -> 1083         return self.compute("nlargest")
#    1084
#    1085     def nsmallest(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1198             if not self.is_valid_dtype_n_method(dtype):
#    1199                 raise TypeError(
# -> 1200                     f"Column {repr(column)} has dtype {dtype}, "
#    1201                     f"cannot use method {repr(method)} with this dtype"
#    1202                 )
#
# TypeError: Column 'Runs_FC' has dtype object, cannot use method 'nlargest' with this dtype

# %% [markdown]
# #### Sunrisers Hyderabad

# %%
srh=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\srh.csv')
df=clean_(srh)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)

# %% [markdown]
# #### Kings XI Punjab

# %%
kxip=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\kxip.csv')
df=clean_(kxip)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 19
# most experienced player age of the team being  41
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                  Mat_FC
# name
# Chris Gayle         404
# Glenn Maxwell       273
# Chris Jordan        201
# Mandeep Singh       165
# Nicholas Pooran     140
# Top Run scorers
# **************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-234-4c2c92fd341d> in <module>
#       6 print("Top Run scorers")
#       7 print("*"*50)
# ----> 8 Most_runs(df)
#       9
#      10
#
# <ipython-input-124-8e31bb19b438> in Most_runs(df)
#       3
#       4 def Most_runs(df):
# ----> 5     print(df[['name','Runs_FC']].nlargest(5, 'Runs_FC').set_index('name'))
#       6
#       7 def Bat_strike(df):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    5123         Brunei      434000    12128      BN
#    5124         """
# -> 5125         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5126
#    5127     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1081
#    1082     def nlargest(self):
# -> 1083         return self.compute("nlargest")
#    1084
#    1085     def nsmallest(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1198             if not self.is_valid_dtype_n_method(dtype):
#    1199                 raise TypeError(
# -> 1200                     f"Column {repr(column)} has dtype {dtype}, "
#    1201                     f"cannot use method {repr(method)} with this dtype"
#    1202                 )
#
# TypeError: Column 'Runs_FC' has dtype object, cannot use method 'nlargest' with this dtype

# %% [markdown]
# #### Rajasthan Royals

# %%
rr=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\rr.csv')
df=clean_(rr)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 19
# most experienced player age of the team being  41
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(df)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                  Mat_FC
# name
# Chris Gayle         404
# Glenn Maxwell       273
# Chris Jordan        201
# Mandeep Singh       165
# Nicholas Pooran     140
# Top Run scorers
# **************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-236-4c2c92fd341d> in <module>
#       6 print("Top Run scorers")
#       7 print("*"*50)
# ----> 8 Most_runs(df)
#       9
#      10
#
# <ipython-input-124-8e31bb19b438> in Most_runs(df)
#       3
#       4 def Most_runs(df):
# ----> 5     print(df[['name','Runs_FC']].nlargest(5, 'Runs_FC').set_index('name'))
#       6
#       7 def Bat_strike(df):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    5123         Brunei      434000    12128      BN
#    5124         """
# -> 5125         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5126
#    5127     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1081
#    1082     def nlargest(self):
# -> 1083         return self.compute("nlargest")
#    1084
#    1085     def nsmallest(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1198             if not self.is_valid_dtype_n_method(dtype):
#    1199                 raise TypeError(
# -> 1200                     f"Column {repr(column)} has dtype {dtype}, "
#    1201                     f"cannot use method {repr(method)} with this dtype"
#    1202                 )
#
# TypeError: Column 'Runs_FC' has dtype object, cannot use method 'nlargest' with this dtype

# %% [markdown]
# #### Delhi Capitals

# %%
dc=pd.read_csv(r'C:\Users\vinodhkumarb\Desktop\IPL\dc.csv')
df=clean_(dc)

# %%
print("Distribution of left and right hander in the team ")
print("*"*50)
Batting_hand(df)

print("Key skill distribution")
print("*"*50)
skill_distribution(df)

print("Age factor")
print("*"*50)
Age_distribution(df)

print("Bowling variety available")
print("*"*50)
Bowling_variation(df)
# Out:
# Distribution of left and right hander in the team
# **************************************************
# Key skill distribution
# **************************************************
# Age factor
# **************************************************
# The average age of the team being  27
# Youngest player age of the team being 20
# most experienced player age of the team being  37
# Bowling variety available
# **************************************************

# %%
print("Most match played")
print("*"*50)
most_match(df)


print("Top Run scorers")
print("*"*50)
Most_runs(mi)


print("Top best players with the best strikerate")
print("*"*50)
Bat_strike(df)


print("Top 5 Best Bowling Average")
print("*"*50)
Bowling_Ave(df)


print("Top 5 Best economy rate")
print("*"*50)
Best_eco(df)


print("Top 5 most wicket in the team")
print("*"*50)
Most_Wks(df)
# Out:
# Most match played
# **************************************************
#                      Mat_FC
# name
# Shikhar Dhawan          261
# Ravichandran Ashwin     233
# Amit Mishra             230
# Ajinkya Rahane          196
# Axar Patel              133
# Top Run scorers
# **************************************************
#                   Runs_FC
# name
# Kieron Pollard      10238
# Rohit Sharma         8734
# Quinton de Kock      5544
# Chris Lynn           5234
# Suryakumar Yadav     3076
# Top best players with the best strikerate
# **************************************************
#                Bat_SR_FC
# name
# Rishabh Pant      155.41
# Harshal Patel     153.81
# Prithvi Shaw      147.86
# Lalit Yadav       136.91
# Shreyas Iyer      130.60
# Top 5 Best Bowling Average
# **************************************************
#                     Bowl_Ave_FC
# name
# Tushar Deshpande          17.93
# Sandeep Lamichhane        18.15
# Daniel Sams               18.36
# Kagiso Rabada             20.91
# Anrich Nortje             22.06
# Top 5 Best economy rate
# **************************************************
#                      Econ_FC
# name
# Sandeep Lamichhane      6.71
# Ravichandran Ashwin     6.87
# Axar Patel              6.90
# Lalit Yadav             6.92
# Amit Mishra             7.17
# Top 5 most wicket in the team
# **************************************************
#                      Wkts_FC
# name
# Amit Mishra              253
# Ravichandran Ashwin      237
# Sandeep Lamichhane       117
# Axar Patel               116
# Kagiso Rabada            112
